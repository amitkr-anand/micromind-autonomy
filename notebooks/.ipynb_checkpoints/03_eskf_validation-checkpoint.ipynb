# %%
# --- MicroMind canonical path setup (DO NOT REMOVE) ---
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

print("Project root added to PYTHONPATH:", PROJECT_ROOT)


from sim.eskf_simulation import run_simulation
import numpy as np
import matplotlib.pyplot as plt

t, pos, att = run_simulation()

plt.figure()
plt.plot(t/60, np.linalg.norm(pos, axis=1))
plt.xlabel("Time (min)")
plt.ylabel("Position Error (m)")
plt.grid()
plt.show()

plt.figure()
plt.plot(t/60, np.rad2deg(att))
plt.xlabel("Time (min)")
plt.ylabel("Attitude Error (deg)")
plt.grid()
plt.show()
# Out:
# Project root added to PYTHONPATH: /Users/amitanand/micromind-autonomy
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 15
#      12 import numpy as np
#      13 import matplotlib.pyplot as plt
# ---> 15 t, pos, att = run_simulation()
#      17 plt.figure()
#      18 plt.plot(t/60, np.linalg.norm(pos, axis=1))
#
# File ~/micromind-autonomy/sim/eskf_simulation.py:111, in run_simulation(config)
#     107 b_g_est = ekf.x[12:15]
#     109 # --- INS propagation
#     110 # Bias injection already done via ESKF
# --> 111 state = ins_propagate(
#     112     state,
#     113     acc_meas,
#     114     gyro_meas,
#     115     dt
#     116 )
#     119 # --- Log outputs
#     120 pos_hist[k] = state.p
#
# File ~/micromind-autonomy/core/ins/mechanisation.py:8, in ins_propagate(state, acc_meas, gyro_meas, dt)
#       5 acc  = acc_meas  - state.ba
#       6 gyro = gyro_meas - state.bg
# ----> 8 dq = quat_from_gyro(gyro, dt)
#       9 q_new = quat_normalize(quat_multiply(state.q, dq))
#      11 acc_world = quat_rotate(q_new, acc) + GRAVITY
#
# NameError: name 'quat_from_gyro' is not defined
